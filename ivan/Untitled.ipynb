# %%
# Importing packages for data analysis
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("sex-by-occupation-for-the-civilian-employed-population-16-years-and-over.csv")
data.head()
# Out:
#         Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 0   Allegheny Center   1             579.0               131.000000
# 1     Allegheny West   2             221.0                80.000000
# 2          Allentown   3             841.0               170.064694
# 3          Arlington   4             991.0               207.465660
# 4  Arlington Heights   5              80.0                57.000000
#
#    Estimate; Male:  Margin of Error; Male:  \
# 0            377.0              112.000000
# 1            133.0               50.000000
# 2            283.0              100.742245
# 3            480.0              127.039364
# 4              0.0               10.000000
#
#    Estimate; Male: - Management, business, science, and arts occupations:  \
# 0                                              232.0
# 1                                               52.0
# 2                                               65.0
# 3                                               54.0
# ...
